# %%
import pandas as pd

df = pd.read_csv("data/processed/transformed_jobs.csv")
print(df["posted_year"].unique())
# Out:
# [2024 2021 2020 2023 2025 2026 2022]

# %%
year_counts = df["posted_year"].value_counts().sort_index()
print("Jobs per year:")
print(year_counts.to_string())
print(f"\nTotal: {year_counts.sum()}")
# Out:
# Jobs per year:
# posted_year
# 2020    4788
# 2021    4800
# 2022    4771
# 2023    4714
# 2024    4870
# 2025    4716
# 2026    5408
#
# Total: 34067

# %%
from ftfy import fix_text

print(fix_text("KÃ¶ln"))
print(fix_text("MÃ¼nster"))
print(fix_text("DÃ©veloppeur"))
# Out:
# Köln
# Münster
# Développeur

# %%
print("Missing before:", df["city"].isnull().sum())
# Out:
# Missing before: 90
