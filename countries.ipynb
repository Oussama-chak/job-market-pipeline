# %%
import pandas as pd

df = pd.read_csv("data/processed/transformed_jobs.csv")
print(df["job_title"].unique())
# Out:
# ['Data Analyst' 'MLOps Engineer' 'AI Researcher' 'Applied Scientist'
#  'Data Scientist' 'Machine Learning Engineer' 'Machine Learning Developer'
#  'Analyst, Credit Risk Model Development' 'ML Data Engineer'
#  'Senior Product Manager - Global Data Platform'
#  'SURE/ Senior Manager, Client Services - AI Evangelist'
#  'Principal Software Development Engineer, MLOps'
#  'Lead Product Marketing Manager, AI'
#  'Director, AI Engineering Operations & Data Engineering'
#  'Software Development Engineer - AI Platform' 'Legal Knowledge Engineer'
#  'Senior GenAI Data Scientist (m/f/d)' 'GCP AI Solution Architect'
#  'Director of Engineering' 'Lead AI/ML Engineer & AI Strategy Lead'
#  'Software Developer' 'AI/ML DevOps Engineer'
#  'Fractional CTO / AI Strategy Council - Remote (Contractor)'
#  'Senior MLOps Engineer | Ingnieure MLOps senior'
#  'Product Line Manager - Global Data and AI Platforms'
#  'Product Group Technology Lead - AI 4 Data Management (AI4DM)'
#  'Product Line Manager – Global Data and AI Platforms'
#  'Technical Product Owner' 'AI Solution Architect'
#  'AI/Machine Learning Ops Engineer' 'Senior Machine Learning QA Developer'
#  'Senior AI Engineer' 'Senior Machine Learning QA Engineer'
#  'Senior MLOps Engineer' 'IT Architect, AI Technical Design'
#  'Senior Data Engineer'
#  'Director, Software Development - AI/ML Solutions and Delivery'
#  'Senior Systems Engineer, Production'
#  'Senior Manager, Software Engineering (Infrastructure)'
#  'Azure AI/Data Architect' 'Associate AI/ML Developer' 'Data/AI Engineer'
#  'AI Engineer' 'Machine Learning Engineer (with Vertex AI Experience)'
#  'Senior MLOps Engineer | Ingénieur·e MLOps senior'
#  'Senior Machine Learning Engineer (GCP)' 'Lead Engineer - AI Voice'
#  'Senior Infrastructure Engineer' 'Senior Quality Engineer'
#  'Senior Manufacturing Operations Manager' 'Financial Manager'
#  'Strategy Consultant - AI Training & Evaluation (MBB & Top-Tier Firms)'
#  'Senior Data Scientist' 'Sr. Business Intelligence Analyst'
#  'Senior Software Engineer' 'Intern Researcher – AI-Native Graphics'
#  'Senior Manager, Data and AI adoption' 'Manufacturing Technician'
#  'Senior Cloud Security Engineer'
#  'Principal Engineer - Data, AI, Platform Development & Support'
#  'Senior Model Risk Specialist, Anti Money Laundering & Fraud'
#  'Credit Risk Modelling Senior Associate' 'Shop Hand'
#  'Data Science Expert - AI Content Specialist'
#  'Legal Operations Associate (Remote)'
#  'XVA Structurer, Counterparty Risk Trading'
#  'Operations Associate (Legal & Compliance)' 'Manager, Data & Analytics'
#  'Senior Software Engineer, Data' 'Senior Product Manager'
#  'Operations Analyst (Legal & Compliance)'
#  'Senior Process Automation Specialist' 'Head of Data Platforms'
#  'Overnight Laundry Attendant - Part Time' 'Tech Lead Manager, Automation'
#  'Manager, NBA Measurement & Analytics'
#  'Senior Analyst Artificial Intelligence'
#  'Solutions Architect II, Cloud AI, Google Cloud'
#  'Software Engineering Manager, Sodatone' 'Graphic Designer, Events'
#  'Computational Scientist Catalyst' 'Microsoft Purview Architect'
#  '2026 CAE, Summer GenAI Engineer (12 months)'
#  'Spécialiste, Machine Learning (SSA) - Machine Learning Specialist (SSA)'
#  'Staff MLOps Engineer' 'Data Product Owner, Portfolio Data Products.'
#  'Consultant, Data Engineer' 'Research Assistant 2'
#  'Software Engineer – Embedded Systems & Computer Vision'
#  'Technical Consultant Hearth' 'Manager, Data Analytics'
#  'Sr. Data Scientist, Alexa Connections'
#  'Advanced Technology Compiler Engineer'
#  'Regional Accounting Expert - FinTech' 'Scrum Master'
#  'Enterprise AWS Cloud Data & AI Architect' 'Principal Applied Scientist'
#  'Software Engineer Embedded Systems & Computer Vision'
#  'Principal Software Developer' 'Senior Solution Engineer - AI Knowledge'
#  'Audit Manager I, Financial Crimes Audit, High Risk Areas (790)'
#  'directeur principal, Analyse, Commerce interrelié et Marketing'
#  'Security Researcher - Authentication and Authorization'
#  'AI & GenAI Solution Architect - Azure Stack' 'Quality Engineer II'
#  'Senior Applied Machine Learning Scientist, Conversational AI (B3617)'
#  'Senior Applied Machine Learning Scientist, Predictive AI(B3617)'
#  'Senior Full Stack Engineer'
#  'ITSM Process Analyst, Deloitte Global Technology'
#  'Senior DevOps Engineer'
#  'Analytics and Process Improvement Specialist - Challenger (Cambridge)'
#  'Product Owner – LMP AI Workflows - Vaccines'
#  'Product Owner - Clinical AI Workflows - Vaccines'
#  'Product Owner – Portfolio AI Workflows'
#  'Regulatory Affairs Project Leader, Chemistry, Manufacturing & Controls (CMC)'
#  'Research Associate in Wireless Communications'
#  'Scientifique en recherche appliquée - Sécurité IA / Applied Research Scientist'
#  'Freelance Data Science Engineer (Python & SQL)'
#  'Data Scientist (Python & SQL) - Freelance AI Trainer' 'Sr. AI Engineer'
#  'Senior Data Scientist /Scientifique de donnes senior'
#  'Machine Operators' 'Sr. Machine Learning Engineer'
#  'Machine Learning Developer (Freelance)'
#  'Software Dev Engineer II, AWS Elemental Inference'
#  'Senior Data Engineering Developer II'
#  'Freelance Machine Learning Engineer'
#  'AI Platform Engineer (DevOps / MLOps Focus)' 'Data Engineering Manager'
#  'AWS MLOps Engineer - London' 'MLOps Engineer - Remote'
#  'AI Solutions Architect' 'Treasury AI Engineering Lead'
#  'AI/ML & Prompt Engineer LLM, RAG & Voice Agent'
#  'Senior Technology Leader' 'Senior Dev/MLOps Engineer'
#  'Head of Data Engineering'
#  'Senior Data Engineer - Azure / DataBricks / PySpark'
#  'Senior ML/MLOps Engineer' 'Senior ML Ops Engineer' 'Lead Data Engineer'
#  'Senior AI & Automation Engineer' 'Lead AI Engineer'
#  'Lead ML Engineer (SageMaker)' 'Staff Software Engineer'
#  'Senior Machine Learning Engineer'
#  'AI Engineer (Contract) – GCP / Startup Experience – Hybrid London'
#  'Head of Data Engineering - McGregor Boyall'
#  'MLOps Engineer - Image - Remote - Outside IR35'
#  'Data Scientist Specialist' 'Data & ML Engineer - Newcastle'
#  'Delivery Manager - Data Engineering' 'Head of AI Practice'
#  'Senior Manager of ML Ops' 'AI Delivery Manager'
#  'Senior Data Platform Engineer' 'Join our growing AI & Cyber Practice'
#  'Head of Data and AI Engineering' 'DevOps Engineer'
#  'Trading Reliability Engineer' 'ML Ops Engineer' 'Principal Engineer'
#  'Director Data Science' 'AWS MLOps Engineer'
#  'Lead AI Architect - Permanent - Hybrid - Insurance'
#  'Senior Data Engineer (IC)'
#  'Senior Machine Learning Engineer, Recommendations'
#  'Senior Machine Learning Engineer, Ranking' 'Engineering Manager'
#  'Staff Software Engineer - AI/ML - MLOps'
#  'Asset & Wealth Management - Software Engineering Manager - Vice President - Birmingham'
#  'Senior ML Engineer / ML Lead' 'Senior Research Engineer'
#  'Lead Machine Learning Engineer - London Stock Exchange Group'
#  'Principal Machine Learning Engineer - London Stock Exchange Group'
#  'Lead ML Engineer'
#  'Senior Solutions Architect / Senior Solutions Engineer - EU'
#  'MLOps Fullstack Engineer' 'Machine Learning Scientist, Ranking'
#  'Developer Relations Engineer III'
#  'SDET (Software Development Engineer in Test)'
#  'ML Ops Engineer - Contract' 'Principal Machine Learning Engineer'
#  'Lead Machine Learning Engineer' 'Infrastructure and MLOps Engineer'
#  'Machine Learning Scientist - Recommendations'
#  'Staff Machine Learning Scientist - Core ML'
#  'ML Engineer / Data Scientist, Applied AI' 'Senior MLOPs Engineer'
#  'Lead Software Engineer - MLOps Platform' 'Azure Data Support Engineer'
#  'Data & ML Platform Engineer' 'Data Scientist - Advanced Analytics'
#  'Data Engineer' 'Data Scientist – Credit Risk & AI Innovation'
#  'Forward Deployed Engineer, ML' 'Software Engineer III - MLOps'
#  'Lead Software Engineer - MLOps' 'Solutions Engineer'
#  'Machine Learning Scientist' 'Head of Data Science'
#  'Principal AI Engineer' 'MLOps Engineer (Madrid, Spain)'
#  'Machine Learning Engineer - Customer Solutions'
#  'Senior Data Enablement Engineer' 'Senior AI Solutions Architect'
#  'EY - GDS Consulting - D&A - Data Scientist - Manager'
#  'EY - GDS Consulting - D&A - Data Scientist - Senior'
#  'EY - GDS Consulting - D&A - Gen AI- Senior'
#  'Senior Machine Learning Scientist - Search' 'Senior Research Scientist'
#  'Lead Architect' 'Sales Development Representative' 'Machine Operator'
#  'Data Architect - Bristol - Hybrid Opportunity'
#  'Doctor Clinical Product Specialist (Home-based/ 30 hours per week)'
#  'Graduate Web Developer' 'Recruitment Consultant'
#  'Data and Statistical Modelling Engineer'
#  'Machine Learning Engineer - £110k – £130k – Geospatial Tech 4 Good'
#  'Graduate Software Engineer' 'Systems Integration Engineer'
#  'Global Head of Equities Quantitative Analysis - Citi'
#  'AWS Data Engineer' 'Senior Data Scientist (Behavioural)'
#  'Junior Software Engineer' 'AI Platform Engineer'
#  'Staff Machine Learning Engineer' 'Backend Software Engineer (Python)'
#  'Data Science Training & Internship - CP' 'Edge AI Engineer'
#  'Summer Intern'
#  'Technologist in Residence - Ecological Citizens (part time) 0.2fte'
#  'Senior Consultant (MBB & Top-Tier Firms) - Freelance AI Project'
#  'Lecturer in Computing' 'Specialised AI Engineer'
#  'Manager, Research Engineering (Foundational Research)'
#  'Senior Product Manager - Fraud Prevention'
#  'Product Engineer - Growth (Remote/GMT)'
#  'Application Scientist (Mesoscale / Coarse Grained Force Fields)'
#  'Senior Product Manager (Anti Money Laundering/Transaction Monitoring)'
#  'Solutions Architect' 'Planning and Engagement Analyst'
#  'Application Engineer' 'AI Specialist'
#  'Senior Associate, Full-Stack Engineer' 'Head of Customer Experience'
#  'AI Bioinformatician' 'Engineering Lead - Analytics Platform'
#  'PhD Research Summer Intern AI/ML & Digital Health'
#  'Software Development Engineer, Ring Cloud Computer Vision'
#  'Solutions Architect - Executive Director' 'PBWM Data Analyst'
#  'Managing Data Scientist' 'Graphics Engineer'
#  'Fraud and Disputes Manager (Cards)'
#  'Digital Marketing Data Scientist (COE)'
#  '(Senior) Product Manager - Name & Payment Screening'
#  '12 month Emerging Talent – Software Development Intern 2026 Opportunities (Cramlington)'
#  'MLOps Engineer für CI / CD & Inference Services (m/w/d)'
#  'Senior MLOps Engineer (f/m/x)'
#  'Senior MLOps / DevOps Engineer AI (Computer Vision) (m/w/d)'
#  'AI Software Engineer (m/f/d)'
#  'Senior MLOps Engineer - Autonomous Driving Platform (f/m/x)'
#  'Senior MLOps Engineer (ML Workflows Engineering)'
#  'MLOps Engineer (m/w/d)'
#  'Lead MLOps Engineer (Multimodal Agentic AI Systems)'
#  'Lead AI Software Architect/Engineer (m/f/d)' 'Head of ML'
#  'AI Engineer / MLOps Engineer'
#  'Senior Software Engineer, ML Ops & Infrastructure'
#  'Teamleiter (m/w/d) Fullstack Softwareentwicklung Search & AI Services'
#  'Lead AI Software Engineer/Architect (m/f/d)'
#  'Senior Computer Vision Engineer (m/f/d)'
#  'Senior Software Architekt – AI‑Driven DevOps (m/w/d)'
#  'Biostatistiker - Omics-Daten (m/w/d)'
#  'Actuarial Data Scientist / Aktuar:in / Mathematiker:in im Pricing (w/m/d)'
#  'Datenschutzexperte (d/m/w)'
#  'Product Intelligence Sensory Manager (m/f/d)'
#  '(Senior) Data Scientist (m/w/d) - Machineseeker Group'
#  'Senior Java Search Engineer (m/f/nb) - Conrad Electronic SE'
#  'Senior Software Engineer (m/f/d)'
#  'W2-Stiftungsprofessur Digitale Medizin und Künstliche Intelligenz in der Augenheilkunde'
#  'Chief Expert - RADAR and ADAS Sensors - Research (SL2, w/m/div.)'
#  'Senior Enterprise Architect (m/w/d)'
#  'Praktikant*in Getriebe- und E-Motoren-Berechnung (Pflicht-Praktikum)'
#  'PhD-Position (m/f/x) at ICAMS, Ruhr-University Bochum: Lattice-Boltzmann-based simulations of reactive flows through particle beds'
#  'Experte (w/m/d) Contact Center AI (Conversational AI & Agentic AI) am Standort Köln'
#  'Senior Application Manager / Solution Engineer – Transaction Reporting m/w/d'
#  'Leiter / Leiterin Entwicklung (m/w/d)'
#  'Praktikum für Studierende im Masterstudium - Inklusiver Job'
#  'Innovation Project Lead Surgery Planning (m/w/d) - Inklusiver Job'
#  'Softwareentwickler (m/w/d) AIRBUS' 'AI Engineer (d/m/w)'
#  'Wissenschaftlerin Textilien, Lederwaren und Schuhe (m/w/d)'
#  'Digital Process Engineer – AI & Automation (KI-Engineer / Machine Learning Engineer / Wirtschaftsinformatiker / Informatiker o.Ä.) (m/w/d)'
#  'Wissenschaftler Textilien, Lederwaren und Schuhe (m/w/d)'
#  'Wissenschaftler Textilien, Lederwaren und Schuhe/Wissenschaftlerin Textilien, Lederwaren und Schuhe (m/w/d)'
#  'Talent Acquisition Expert – Schwerpunkt Active Sourcing (w/m/d)'
#  'KI-Applikationsentwickler (m/w/d) im genetikum Neu-Ulm'
#  'Senior Entwickler (m/w/d) für objektorientierte Programmierung – 60% Homeoffice möglich in 66450 Bexbach'
#  'AI Engineer (m/w/d)'
#  'Technischer Produkt Manager (m/w/d) Traineeprogramm'
#  'Senior Fullstack Softwareentwickler (m/w/d) KI-Lösungen, InsurTech'
#  'Associate Product Owner (m/w/d) Traineeprogramm'
#  'Software Entwickler C++ Architektur (m/w/d) militärischer Schiffbau'
#  'Cloud Engineer (m/w/d)'
#  'KI Consultant HR Tech (m/w/d) Zukunft gestalten mit KI'
#  'Werkstudent AI Education (m/w/d)' 'Senior Front-End Developer (m/f/d)'
#  'Duales Studium (B.Sc.) - Data Science und Künstliche Intelligenz (m/w/d)'
#  'Senior Data Scientist mit Schwerpunkt E-Commerce (m/w/d) - Datenbankentwicklung/BI, Ingenieur'
#  'AIOps Engineer* (m/w/d) - Anwendungsentwicklung, Ingenieur'
#  'Product Owner Data Intelligence Platform (m/w/d) - Datenbankentwicklung/BI, Produktmanagement, Ingenieur'
#  'Senior Data Scientist Schwerpunkt Sortiments\xadmanagement (m/w/d) - Datenbankentwicklung/BI, Ingenieur'
#  'Masterstudent/in (w/m/d): Informatik, Machine Learning, Data Science - Forschung, Ingenieur'
#  'IT Project Manager (w/m/d) - Projektmanagement, Ingenieur'
#  'AI Specialist - Engineering und Data Science (w/m/d) - System Engineering / Admin, Datenbankentwicklung/BI, Ingenieur'
#  'Werkstudent (m/w/d) - Technical Business Analyst & Workflow - Business Analysis, Ingenieur'
#  'AI Architect (all genders) - Projektmanagement, System Engineering / Admin, Ingenieur'
#  'Data Engineer (m/w/d) - Datenbankentwicklung/BI, Ingenieur'
#  'PhD Position in Physics-Based Machine Learning Modeling (m/w/d)'
#  'Research Engineer for Large Time-Series Models (f/m/div.)'
#  'Systems Engineer M/F/X'
#  'Softwareentwickler (m/w/d) für Produktionsoptimierung'
#  'PhD position in physics-based machine learning modeling'
#  'Experte/Expertin für KI und Prozessoptimierung (m/w/d)'
#  'AI Process & Application Engineer (m/w/d)' 'Automation Engineer (m/w/d)'
#  'Senior ML Ops Engineer (f/m/x)'
#  'Wissenschaftliche Mitarbeiterin/Wissenschaftlicher Mitarbeiter (m/w/d) für Operations Research'
#  'IT-Projektbetreuer Künstliche Intelligenz (m/w/d) - Abtsgmünd'
#  'Software Developer Payload Management (m/w/d)'
#  'AI Software Engineer (m/w/d)'
#  'Data Steward (f/m/d) - Munich Data Science Institute'
#  'Auszubildende Fachinformatiker/in Anwendungsentwicklung'
#  'Auszubildende/r Fachinformatiker/in Systemintegration'
#  'AI Engineer (f/m/x) - Dortmund' 'AI Engineer (f/m/x) - Berlin'
#  'Senior Applied ML Engineer (gn)'
#  'Ausbildung Fachinformatiker/in (w/m/d) - Anwendungsentwicklung'
#  'Senior Applied ML Engineer (m/w/d)' 'Applied ML Engineer (m/w/x)'
#  'Senior DevOps Engineer (m/f/d)'
#  'Praktikum Data Science M/F/X - Crailsheim'
#  'Praktikum Data Science M/F/X' 'Praktikum Data Science M/F/X - Berlin'
#  'Praktikum Data Science M/F/X - Stuttgart'
#  'Praktikum Data Science M/F/X - Munich'
#  'Praktikum Data Science M/F/X - Cologne'
#  'Praktikum Data Science M/F/X - Düsseldorf'
#  'Praktikum Data Science M/F/X - Hamburg'
#  'Praktikum Data Science M/F/X - Hanover'
#  'Praktikum Data Science M/F/X - Frankfurt'
#  'Praktikum Data Science M/F/X - de'
#  'Praktikum Data Science M/F/X - Leipzig'
#  'Praktikum Data Science M/F/X - Bretten' 'Senior Data Scientist (m/w/d)'
#  'Senior Fullstack Softwareentwickler (m/w/d) KI-Lösungen'
#  'Data Science Internship M/F/X'
#  'Praktikum Data Science M/F/X - Heidelberg' 'Azure AI Consultant (m/w/d)'
#  'AI Engineering Lead (m/w/d)' 'Wirtschaftsinformatiker' 'Informatiker'
#  'Duales Studium zum Bachelor of Science – Data Science & Künstliche Intelligenz 2027 (m/w/d)'
#  'Product Owner Data (m/w/d)'
#  'Duales Studium Angewandte Künstliche Intelligenz (M.Sc.) - Einstieg Data Science'
#  'Duales Studium Data Science und Künstliche Intelligenz B.Sc. (m/w/d), Karlsruhe, 2026'
#  'Duales Studium Business Data Analytics (M.Sc.) mit Schwerpunkt KI - Einstieg Data Science'
#  'Duales Studium Wirtschaftsinformatik - Data Science 2026'
#  'Spezialist Finanzen & Digitalisierung Außenhandel'
#  'Fullstack-Entwickler Engineer AI (m/w/d) 80.000€ Remote'
#  'Fullstack-Entwickler AI DevSecOps (m/w/d) 90.000€ Remote'
#  'Fullstack-Entwickler KI-Python (m/w/d) 85.000€ Remote'
#  'Innovation Project Manager Surgical Planning (f/m/d)'
#  'Softwareingenieur (m/w/d)' 'Anwendungsentwickler (m/w/d)'
#  'Software Engineer, Search Ranking' 'Senior Data Expert (m/w/d)'
#  'Back-End Engineer - Team Agents' '2026 Working Student - Creative'
#  'Senior Data Analyst'
#  'Lead Engineer (Java/Python) Service Platforms and AI (f/m/x)'
#  'Stellenangebot Data Scientist (m/w/d) bei CHEFS CULINAR West GmbH & Co. KG'
#  'Stagiaire finance stratégique / Strategic Finance Intern'
#  'MLOps Support Engineer (L2)(Local to PA)'
#  'Resident Solution Architect - MLOPS Expert' 'Sr. Gen AI Engineer'
#  'MLOps Engineer - AWS, Machine Learning, Sagemaker, GitLab, Terraform'
#  'MLOps Engineer - W2 Only'
#  'Site Reliability/Observability Engineer (SREs)'
#  'Cloud Engineer - REMOTE' 'Sr. AI Engineer – LLMOps & MLOps'
#  'AI Integration Specialist with Security Clearance'
#  'Data Software Engineer III- ML'
#  'Program Manager, Developer Marketing - Community'
#  'Software Engineer III - Data Engineering and MLOps'
#  'Customer Success Manager - Enterprise' 'AI Sr. Engineer LLMOps & MLOps'
#  'AI InfraOps Associate Manager'
#  'Senior Systems Engineer, CoreAI - Agentic Solutions (Remote)'
#  'Senior AI Engineer LLMOps And MLOps - Remote / Telecommute'
#  'AI Sr. Engineer – LLMOps & MLOps' 'Sr. AI Engineer LLMOps & MLOps'
#  'Solution Architect Data Integration' 'AI Engineer - MLOps'
#  'Cloud Data Architect' 'Head of Engineering'
#  'Manager AI & ML Engineering'
#  'Principal, Head of Data & AI Transformation Programs'
#  'Data Science Manager, GenAI - SFL Scientific'
#  'Senior AI Engineer / Solutions Architect - SFL Scientific'
#  'Data Science Manager, Life Sciences & Healthcare - SFL Scientific'
#  'AI Engineering Manager/Solutions Architect - SFL Scientific'
#  'Cloud and Data Architect///Inperson interview'
#  'Cloud and Data Architect (Hybrid)' 'AI Systems Engineer'
#  'AI Technical Product Architect' 'AIML Engineer/ Data Scientist'
#  'Gen AI Lead :: 100 % Remote :: Only W2'
#  'FS / PR, Business Consulting – Payments Functional Program Manager'
#  'Sales Manager – GPU Compute & AI Model APIs'
#  'ML Platform & Infrastructure Engineer' 'Staff Data Scientist'
#  'AI Architect' 'Manager, Data Science (GenAI Solutions & ML Engineering)'
#  'AI Platform Architect (Teradyne, North Reading)'
#  'AI MLOps Engineer- Reading PA - Onsite-In Person Interview'
#  'Senior MLOps Platform Engineer {S} with Security Clearance'
#  'Enterprise Architect' 'Enterprise Data & Cloud Architecture'
#  'Senior Machine Learning Engineer (Op AI) - TS clearance - N. Cha with Security Clearance'
#  'Senior Data Architect - Remote / Telecommute' 'AI/MLOps Engineer'
#  'Generative AI Engineer - Remote / Telecommute'
#  'AI/ML Engineer III with Security Clearance'
#  'Agentic AI Solutions Architect with Security Clearance'
#  'AI Integration engineer with Security Clearance'
#  'MLOps Engineer — AI/ML Systems & Deployment (TS/SCI Preferred) with Security Clearance'
#  'AI Software Engineer'
#  'Data Scientist - Camden NJ ( local candidates only)'
#  'Machine Learning Ops Engineer Brand Concierge'
#  'Solution Architect, Data Science and AI' 'MLOps Platform Engineer'
#  'AI/ML Engineer' 'Machine Learning Engineer Remote'
#  'ML Ops Engineer, Machine Learning & AI' 'MLOps and ML Engineer'
#  'Senior ML Engineer' 'Director, Compliance Data Science & AI'
#  'Senior Generative AI Engineer- FULLTIME- NO C2C'
#  'AI Enterprise Architect'
#  'DE Senior Architect-Google Cloud Platform Architect'
#  'MLOps/ Xops Engineer - Reading PA - Onsite -F2F interview for client round'
#  'GenAI and MLOPS'
#  'Hiring for Machine Learning Engineer :: Remote or Boston, MA/ St. Louis, MO'
#  'Databricks MLOps Engineer' 'Data Platform Engineer'
#  'ML OPS Engineer-San Jose, CADay 1 OnsiteINDEPENDENT CANDIDATES ONLY'
#  'Machine Learning Engineer Operations Engineer'
#  'SVP, MLOps / DevOps Engineer - Full Time - Hybrid'
#  'Senior DevOps Engineer with AI/ML : Cumming, GA-Hybrid'
#  'Software - Machine Learning Engineer'
#  'MLOps Engineer with Azure Databricks, Data Factory, Python'
#  'Artificial Intelligence/Machine Learning Developer (TS/SCI with Polygraph Required)'
#  'Sr. Data Scientist' 'Generative AI Engineer'
#  'Senior Platform Engineer / MLOps / DevOps / Chicago' 'MLOPS Engineer'
#  'MLOps/ Xops Engineer'
#  'Senior Solutions Architect with AWS and GenAI experience'
#  'Google Cloud Platform MLOPs Tech Lead - Python, Google Cloud Platform (Google Cloud Platform)  Direct End Client'
#  'AI ML engineer with Agentic AI experience'
#  'Azure DevOps Engineer/ MLOps'
#  'MLOps Engineer:: Reading, Pennsylvania, Work from Client location, 5 days a week'
#  'DevOps Specialist'
#  'DevOps Engineer Cloud, Automation, and MLOps  Direct end client'
#  'AWS Data Science/MLOps Engineer - Onsite Interview'
#  'Senior MLOps/AIOps Engineer with DevSecOps' 'AI/ML Architect'
#  'Immediate Need -AI MLOps Engineer - Reading PA, Onsite. Must attend F2F. Preferred only locals or near by. Need skils Xops, Devops, MLops, Python, IaC, Ci/CD, Devops, AWS Security & Identity, Bedrock Agentcore, LangGraph, CrewAI, MCP, AWS AI'
#  'Healthcare Senior NLP / LLM Engineer (MLOps & AWS)-Onsite Role,Need Local to TX'
#  'Backend AI Engineer' 'Lead MLOps Engineer - Azure'
#  'Senior Director of Software Engineering – AI/ML & Ontology'
#  'Director Engineering - AI/ML'
#  'Lead Software Engineer - DevOps / Full-Stack / MLOps'
#  'AI/ML Engineer III' 'Director of Artificial Intelligence'
#  'Applied Machine Learning Engineer - ML & AI Systems'
#  'Senior Platform/MLOps Engineer' 'AI Marketing Agent Product Manager'
#  'Client Success Principal Consultant'
#  'Microsoft Azure Cloud and Enterprise Data Architect'
#  'Principal Analytics & ML Engineer' 'Head of Applied AI Products'
#  'Manager, Technology Risk Consulting - AI and Emerging Technology Risk'
#  'Manager, AI Operations and Enablement'
#  'Applied AI/ML Data Scientist - Vice President'
#  'Data Science Associate Manager' 'Sr Staff AI Engineer'
#  'Senior AWS Full Stack ML Engineer'
#  'Senior IT AI/ML Engineer - Data Analytics' 'Lead Data Scientist'
#  'Principal Machine Learning Platform Engineer (Prisma AIRS)'
#  'Senior AI Engineer - Generative AI & Applied Innovation (Financial Services)'
#  'Agentic AI Machine Learning Engineer' 'Agentic AI Solutions Architect'
#  'ServiceNow Assist Developer'
#  'Cyber - Identity & Cryptography- Architect']

# %%
print(
    (df["salary_min_usd"] == df["salary_max_usd"]).sum()
)
# Out:
# 352
