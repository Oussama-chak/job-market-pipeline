# %%
import pandas as pd

df = pd.read_csv("data/processed/unified_jobs.csv")
print(df["job_title"].unique())
# Out:
# ['Data Analyst' 'MLOps Engineer' 'AI Researcher' 'Applied Scientist'
#  'Data Scientist' 'Machine Learning Engineer'
#  'MLOps Engineer für CI / CD & Inference Services (m/w/d)'
#  'Senior MLOps Engineer (f/m/x)'
#  'Senior MLOps / DevOps Engineer AI (Computer Vision) (m/w/d)'
#  'AI Software Engineer (m/f/d)'
#  'Senior MLOps Engineer - Autonomous Driving Platform (f/m/x)'
#  'Senior MLOps Engineer (ML Workflows Engineering)'
#  'Fullstack-Entwickler:in'
#  'Informatiker als IT Business Analyst - Data Warehouse (w/m/d)'
#  'Stellenangebot Data Analyst (m/w/d) bei CHEFS CULINAR West GmbH & Co. KG'
#  'Senior Data Analyst' 'Senior Machine Learning Engineer, Recommendations'
#  'Lead Software Architekt (m/w/d)' 'Data Analyst (m/w/d)'
#  'Senior Data & AI Analyst (w/d/m)' 'Senior Insights Analyst (Mensch)'
#  'Applied AI Scientist (Pharma Partnerships)'
#  'Senior Principal Product Manager - - Developer Experience / Cloud Platform (All Genders)'
# ...
